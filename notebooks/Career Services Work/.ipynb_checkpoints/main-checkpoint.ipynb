# %%
import polars as pl

# 1. Load the dataset
df = pl.read_csv("../../Data/final.csv")

# Update schema
edu_schema = pl.List(pl.Struct({
    "university": pl.String,
    "degree_standardized": pl.String,
    "start_date": pl.String,
    "end_date": pl.String
}))

target_universities = [
    "BUV", "British University Vietnam", "Swinburne", "FUV", 
    "Fulbright University Vietnam", "RMIT", "Royal Melbourne Institute of Technology Vietnam",
    "VinUniversity"
]
pattern = "|".join([uni.lower() for uni in target_universities])
target_years = ["2027-01-01", "2026-01-01", "2025-01-01", "2024-01-01"]

# The degrees that disqualify a candidate if completed BEFORE the target degree
advanced_degrees = ["bachelor", "master", "phd", "architect", "engineer"]

# 2. Decode JSON and apply native list evaluations
matching_ids = (
    df.select(["id", pl.col("educations").str.json_decode(edu_schema).alias("edu_structs")])
    .with_columns([
        # Mask 1: Identify the target degree
        pl.col("edu_structs").list.eval(
            pl.element().struct.field("university").str.to_lowercase().str.contains(pattern) &
            (pl.element().struct.field("degree_standardized") == "bachelor") &
            pl.element().struct.field("end_date").is_in(target_years)
        ).alias("target_mask"),
        
        # Array 1: Extract end dates ONLY for advanced/bachelor degrees. 
        # "college" and "high school" will become null and get ignored.
        pl.col("edu_structs").list.eval(
            pl.when(pl.element().struct.field("degree_standardized").is_in(advanced_degrees))
            .then(pl.element().struct.field("end_date").str.strptime(pl.Date, "%Y-%m-%d", strict=False))
            .otherwise(None)
        ).alias("advanced_end_dates"),
        
        # Array 2: Extract all start dates
        pl.col("edu_structs").list.eval(
            pl.element().struct.field("start_date").str.strptime(pl.Date, "%b %Y", strict=False)
        ).alias("all_start_dates")
    ])
    .with_columns(
        # Extract the start date of the specific target degree
        pl.col("all_start_dates").list.get(pl.col("target_mask").list.arg_max()).alias("target_start_date")
    )
    .filter(
        # Condition A: Must have the target degree
        pl.col("target_mask").list.any() & 
        
        # Condition B: The earliest end_date of any ADVANCED degree must not be before the target start_date.
        # This completely ignores prior college/high school degrees.
        (
            pl.col("advanced_end_dates").list.drop_nulls().list.min() >= pl.col("target_start_date")
        ).fill_null(True) 
    )
    .select("id")
    .unique()
)

# 3. Filter the original DataFrame and export to CSV
filtered_df = df.join(matching_ids, on="id", how="inner")
filtered_df.write_csv("fresh-grad-filter-new.csv")
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[15], line 47
#      20 target_years = ["2027-01-01", "2026-01-01", "2025-01-01", "2024-01-01"]
#      22 # 2. Decode JSON and apply native list evaluations
#      23 matching_ids = (
#      24     df.select(["id", pl.col("educations").str.json_decode(edu_schema).alias("edu_structs")])
#      25     .with_columns([
#      26         # Mask 1: Identify which element in the list is the target degree
#      27         pl.col("edu_structs").list.eval(
#      28             pl.element().struct.field("university").str.to_lowercase().str.contains(pattern) &
#      29             (pl.element().struct.field("degree_standardized") == "bachelor") &
#      30             pl.element().struct.field("end_date").is_in(target_years)
#      31         ).alias("target_mask"),
#      32
#      33         # Array 1: Extract and parse all end dates into actual Date objects
#      34         pl.col("edu_structs").list.eval(
#      35             pl.element().struct.field("end_date").str.strptime(pl.Date, "%Y-%m-%d", strict=False)
#      36         ).alias("all_end_dates"),
#      37
#      38         # Array 2: Extract and parse all start dates into actual Date objects (e.g., "Jan 2011")
#      39         pl.col("edu_structs").list.eval(
#      40             pl.element().struct.field("start_date").str.strptime(pl.Date, "%b %Y", strict=False)
#      41         ).alias("all_start_dates")
#      42     ])
#      43     .with_columns(
#      44         # Extract the specific start date of the target degree using the index of the first True in the target_mask
#      45         pl.col("all_start_dates").list.get(pl.col("target_mask").list.arg_max()).alias("target_start_date")
#      46     )
# ---> 47     .filter(
#      48         # Condition A: The candidate must have at least one target degree
#      49         pl.col("target_mask").list.any() &
#      50
#      51         # Condition B: The candidate must NOT have any degree that ended strictly before the target degree started
#      52         # This allows overlaps (where end_date >= target_start_date) but catches truly prior degrees.
#      53         ~pl.col("all_end_dates").list.eval(
#      54             pl.element() < pl.col("target_start_date")
#      55         ).list.any()
#      56     )
#      57     .select("id")
#      58     .unique()
#      59 )
#      61 # 3. Filter the original DataFrame and export to CSV
#      62 filtered_df = df.join(matching_ids, on="id", how="inner")
#
# File ~/graph-database/jupyter_env/lib/python3.12/site-packages/polars/dataframe/frame.py:5345, in DataFrame.filter(self, *predicates, **constraints)
#    5185 """
#    5186 Filter rows, retaining those that match the given predicate expression(s).
#    5187
#    (...)   5338 └──────┴──────┴─────┘
#    5339 """
#    5340 from polars.lazyframe.opt_flags import QueryOptFlags
#    5342 return (
#    5343     self.lazy()
#    5344     .filter(*predicates, **constraints)
# -> 5345     .collect(optimizations=QueryOptFlags._eager())
#    5346 )
#
# File ~/graph-database/jupyter_env/lib/python3.12/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/graph-database/jupyter_env/lib/python3.12/site-packages/polars/lazyframe/opt_flags.py:324, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     321         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     323 kwargs["optimizations"] = optflags
# --> 324 return function(*args, **kwargs)
#
# File ~/graph-database/jupyter_env/lib/python3.12/site-packages/polars/lazyframe/frame.py:2429, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2427 # Only for testing purposes
#    2428 callback = _kwargs.get("post_opt_callback", callback)
# -> 2429 return wrap_df(ldf.collect(engine, callback))
#
# ComputeError: named columns are not allowed in `eval` functions; consider using `element`
