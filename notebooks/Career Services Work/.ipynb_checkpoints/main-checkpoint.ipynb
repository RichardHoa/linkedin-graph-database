# %%
import polars as pl

# Load the CSV file
df = pl.read_csv("../Data/fresh-grad-filter.csv")

# Define the schema for the educations JSON structure
# Based on your final_structure.json, educations is a list of objects
education_schema = pl.List(
    pl.Struct([
        pl.Field("degree_user_input", pl.String),
        pl.Field("degree_standardized", pl.String),
        pl.Field("university", pl.String),
        pl.Field("major_user_input", pl.String),
        pl.Field("major_standardized", pl.String),
        pl.Field("description", pl.String),
        pl.Field("start_date", pl.String),
        pl.Field("end_date", pl.String),
    ])
)

# Parse JSON strings to structs, then extract university
df_with_universities = (
    df
    # Parse the JSON string in 'educations' column with explicit dtype
    .with_columns(
        pl.col("educations").str.json_decode(dtype=education_schema, infer_schema_length=1000)
    )
    # Explode the list to get one row per education entry
    .explode("educations")
    # Extract the university field from each education struct
    .with_columns(
        pl.col("educations").struct.field("university").alias("university")
    )
    # Filter out null universities (though presence_pct is 100%)
    .filter(pl.col("university").is_not_null())
)

# Count frequencies and get top 100 most popular universities
top_100_universities = (
    df_with_universities
    .group_by("university")
    .agg(pl.len().alias("frequency"))
    .sort("frequency", descending=True)
    .limit(100)
)

# Display the results
print("Top 100 Most Popular Universities:")
print("=" * 70)
for i, row in enumerate(top_100_universities.rows(), 1):
    uni_name = row[0] if len(row[0]) <= 55 else row[0][:52] + "..."
    print(f"{i:3d}. {uni_name:55s} - {row[1]:>8,} occurrences")

# Optionally save to CSV
top_100_universities.write_csv("top_100_universities.csv")

# Show summary statistics
print("\n" + "=" * 70)
print(f"Total unique universities: {df_with_universities['university'].n_unique():,}")
print(f"Total education entries processed: {len(df_with_universities):,}")
# Out:
# Top 100 Most Popular Universities:
# ======================================================================
#   1. RMIT University Vietnam                                 -   10,160 occurrences
#   2. RMIT University                                         -    3,724 occurrences
#   3. Swinburne University of Technology                      -    1,112 occurrences
#   4. British University Vietnam                              -      796 occurrences
#   5. Fulbright University Vietnam                            -      640 occurrences
#   6. VinUniversity                                           -      351 occurrences
#   7. RMIT Vietnam                                            -      306 occurrences
#   8. Staffordshire University                                -      242 occurrences
#   9. RMIT International University Vietnam                   -      175 occurrences
#  10. Monash University                                       -      140 occurrences
#  11. Foreign Trade University                                -      138 occurrences
#  12. RMIT                                                    -      133 occurrences
#  13. University Of Economics Ho Chi Minh City                -      109 occurrences
#  14. Hanoi-Amsterdam High School for the Gifted              -       99 occurrences
#  15. RMIT International University                           -       91 occurrences
#  16. RMIT Vietnam University                                 -       85 occurrences
#  17. Le Hong Phong High School For The Gifted, HCMC, Vietnam -       79 occurrences
#  18. VNU-HCM High School for the Gifted                      -       68 occurrences
#  19. Foreign Language Specialized School                     -       65 occurrences
#  20. La Trobe University                                     -       65 occurrences
#  21. Vietnam National University, Hanoi                      -       63 occurrences
#  22. Tran Dai Nghia Specialized High School                  -       63 occurrences
#  23. University of Melbourne                                 -       57 occurrences
#  24. Western Sydney University                               -       56 occurrences
#  25. University of Greenwich                                 -       54 occurrences
#  26. Chu Van An National High School                         -       54 occurrences
#  27. Deakin University                                       -       52 occurrences
#  28. Macquarie University                                    -       48 occurrences
#  29. International University - VNU HCMC                     -       45 occurrences
#  30. University of Staffordshire                             -       42 occurrences
#  31. University of Technology Sydney                         -       41 occurrences
#  32. ACCA                                                    -       41 occurrences
#  33. National Economics University (Vietnam)                 -       38 occurrences
#  34. Tran Phu Gifted High School                             -       36 occurrences
#  35. Singapore Institute of Management                       -       36 occurrences
#  36. UNIVERSITY OF SOCIAL SCIENCES AND HUMANITIES (USSH)     -       35 occurrences
#  37. SIM Global Education                                    -       35 occurrences
#  38. Hanoi University of Science and Technology              -       35 occurrences
#  39. VNUHCM - University of Science                          -       34 occurrences
#  40. National Economics University (NEU) Vietnam             -       34 occurrences
#  41. Ho Chi Minh University of Technology                    -       32 occurrences
#  42. CFA Institute                                           -       30 occurrences
#  43. FPT University                                          -       30 occurrences
#  44. CPA Australia                                           -       30 occurrences
#  45. Hanoi University                                        -       29 occurrences
#  46. High School for Gifted Students, Hanoi National Univ... -       28 occurrences
#  47. Ho Chi Minh City University of Technology               -       28 occurrences
#  48. University of Sydney                                    -       28 occurrences
#  49. RMIT University, Vietnam                                -       27 occurrences
#  50. Hoa Sen University (Not for Profit)                     -       27 occurrences
#  51. Saigon International College                            -       27 occurrences
#  52. UNSW                                                    -       26 occurrences
#  53. Victoria University                                     -       26 occurrences
#  54. Le Quy Don High School for the Gifted                   -       25 occurrences
#  55. Ho Chi Minh City University of Law (ULAW)               -       25 occurrences
#  56. Bournemouth University                                  -       24 occurrences
#  57. University of London                                    -       23 occurrences
#  58. Quốc Học – Huế High School for the Gifted               -       22 occurrences
#  59. RMIT International University, Vietnam                  -       21 occurrences
#  60. Vietnam Australia International School                  -       20 occurrences
#  61. Humber College                                          -       20 occurrences
#  62. Curtin University                                       -       20 occurrences
#  63. National University of Singapore                        -       20 occurrences
#  64. Banking University of Ho Chi Minh City                  -       20 occurrences
#  65. The University of Queensland                            -       20 occurrences
#  66. University of Economics and Law                         -       20 occurrences
#  67. Diplomatic Academy of Vietnam                           -       19 occurrences
#  68. High School for Gifted Students, Hanoi University of... -       19 occurrences
#  69. University of Southampton                               -       19 occurrences
#  70. French Vietnamese School of Management (CFVG)           -       19 occurrences
#  71. Griffith University                                     -       19 occurrences
#  72. Massey University                                       -       18 occurrences
#  73. George Brown College                                    -       18 occurrences
#  74. RMIT Vietnam International University                   -       18 occurrences
#  75. Victoria University of Wellington                       -       18 occurrences
#  76. Monash College                                          -       17 occurrences
#  77. Nguyen Thi Minh Khai High School, HCM                   -       17 occurrences
#  78. Nguyen Thuong Hien High School For The Gifted, HCMC,... -       17 occurrences
#  79. Nguyen Hue High School for the Gifted                   -       17 occurrences
#  80. Vinschool                                               -       17 occurrences
#  81. Academy of Finance, Hanoi, Vietnam                      -       17 occurrences
#  82. Ho Chi Minh City Open University                        -       17 occurrences
#  83. BUV                                                     -       17 occurrences
#  84. Columbia International College                          -       16 occurrences
#  85. University of the West of England                       -       16 occurrences
#  86. Nanyang Technological University Singapore              -       16 occurrences
#  87. High School for Gifted Students, Hanoi University of... -       16 occurrences
#  88. Columbia Southern University                            -       16 occurrences
#  89. Golden Gate University                                  -       16 occurrences
#  90. Solvay Brussels School                                  -       16 occurrences
#  91. CPA Australia Program                                   -       16 occurrences
#  92. Bach Khoa University (fomerly Ho Chi Minh City Unive... -       15 occurrences
#  93. University of Portsmouth                                -       15 occurrences
#  94. Coventry University                                     -       15 occurrences
#  95. Seattle Central College                                 -       15 occurrences
#  96. QUT (Queensland University of Technology)               -       14 occurrences
#  97. Singapore International School (SIS)                    -       14 occurrences
#  98. Phan Chau Trinh High School of Danang                   -       14 occurrences
#  99. Northeastern University                                 -       14 occurrences
# 100. Hoa Sen University                                      -       14 occurrences
#
# ======================================================================
# Total unique universities: 4,551
# Total education entries processed: 28,109
# /tmp/ipykernel_133107/1868129610.py:26: DeprecationWarning: `Expr.str.json_decode` with `infer_schema_length` is deprecated and has no effect on execution.
#   pl.col("educations").str.json_decode(dtype=education_schema, infer_schema_length=1000)

# %%
import polars as pl

# 1. Load the dataset
df = pl.read_csv("../Data/final.csv")


# 3. Count occurrences for an array of university names
target_universities = ["BUV", "British University Vietnam", "Swinburne", "FUV", "Fulbright University Vietnam", "RMIT","Royal Melbourne Institute of Technology Vietnam","VinUniversity","VIN"]

# Parse the JSON strings, explode the list into individual rows, and extract the university field
df_unis = (
    df.select(pl.col("educations").str.json_decode(edu_schema))
    .explode("educations")
    .select(pl.col("educations").struct.field("university").str.to_lowercase().alias("uni_name"))
    .filter(pl.col("uni_name").is_not_null())
)

# Compute the case-insensitive substring match count for each name in the array
university_counts = {
    uni: df_unis.filter(pl.col("uni_name").str.contains(uni.lower())).height
    for uni in target_universities
}

print("University Occurrences:", university_counts)
# Out:
# University Occurrences: {'BUV': 29, 'British University Vietnam': 841, 'Swinburne': 1149, 'FUV': 1, 'Fulbright University Vietnam': 642, 'RMIT': 15165, 'Royal Melbourne Institute of Technology Vietnam': 3, 'VinUniversity': 353, 'VIN': 3963}

# %%
import polars as pl

# 1. Load the dataset
df = pl.read_csv("../Data/final.csv")

# Update schema to include degree_standardized
edu_schema = pl.List(pl.Struct({
    "university": pl.String,
    "degree_standardized": pl.String
}))

# Target universities list
target_universities = [
    "BUV", "British University Vietnam", "Swinburne", "FUV", 
    "Fulbright University Vietnam", "RMIT", "Royal Melbourne Institute of Technology Vietnam",
    "VinUniversity"
]
pattern = "|".join([uni.lower() for uni in target_universities])

# 2. Extract unique row IDs matching both university and bachelor degree criteria
matching_ids = (
    df.select(["id", pl.col("educations").str.json_decode(edu_schema)])
    .explode("educations")
    .filter(
        (pl.col("educations").struct.field("university").str.to_lowercase().str.contains(pattern)) &
        (pl.col("educations").struct.field("degree_standardized") == "bachelor")
    )
    .select("id")
    .unique()
)

# 3. Filter the original DataFrame and export to CSV
filtered_df = df.join(matching_ids, on="id", how="inner")
filtered_df.write_csv("../Data/fresh-grad-filter.csv")
