# %%
import polars as pl

# Load the CSV file
df = pl.read_csv("./fresh-grad-filter.csv")

# Define the schema for the educations JSON structure
# Based on your final_structure.json, educations is a list of objects
education_schema = pl.List(
    pl.Struct([
        pl.Field("degree_user_input", pl.String),
        pl.Field("degree_standardized", pl.String),
        pl.Field("university", pl.String),
        pl.Field("major_user_input", pl.String),
        pl.Field("major_standardized", pl.String),
        pl.Field("description", pl.String),
        pl.Field("start_date", pl.String),
        pl.Field("end_date", pl.String),
    ])
)

# Parse JSON strings to structs, then extract university
df_with_universities = (
    df
    # Parse the JSON string in 'educations' column with explicit dtype
    .with_columns(
        pl.col("educations").str.json_decode(dtype=education_schema, infer_schema_length=1000)
    )
    # Explode the list to get one row per education entry
    .explode("educations")
    # Extract the university field from each education struct
    .with_columns(
        pl.col("educations").struct.field("university").alias("university")
    )
    # Filter out null universities (though presence_pct is 100%)
    .filter(pl.col("university").is_not_null())
)

# Count frequencies and get top 100 most popular universities
top_100_universities = (
    df_with_universities
    .group_by("university")
    .agg(pl.len().alias("frequency"))
    .sort("frequency", descending=True)
    .limit(100)
)

# Display the results
print("Top 100 Most Popular Universities:")
print("=" * 70)
for i, row in enumerate(top_100_universities.rows(), 1):
    uni_name = row[0] if len(row[0]) <= 55 else row[0][:52] + "..."
    print(f"{i:3d}. {uni_name:55s} - {row[1]:>8,} occurrences")

# Optionally save to CSV
top_100_universities.write_csv("top_100_universities.csv")

# Show summary statistics
print("\n" + "=" * 70)
print(f"Total unique universities: {df_with_universities['university'].n_unique():,}")
print(f"Total education entries processed: {len(df_with_universities):,}")
# Out:
# Top 100 Most Popular Universities:
# ======================================================================
#   1. RMIT University Vietnam                                 -    8,901 occurrences
#   2. RMIT University                                         -    3,058 occurrences
#   3. Swinburne University of Technology                      -      679 occurrences
#   4. British University Vietnam                              -      649 occurrences
#   5. Fulbright University Vietnam                            -      375 occurrences
#   6. VinUniversity                                           -      304 occurrences
#   7. RMIT Vietnam                                            -      267 occurrences
#   8. Staffordshire University                                -      204 occurrences
#   9. RMIT International University Vietnam                   -      161 occurrences
#  10. Monash University                                       -      111 occurrences
#  11. RMIT                                                    -       97 occurrences
#  12. Hanoi-Amsterdam High School for the Gifted              -       92 occurrences
#  13. RMIT International University                           -       85 occurrences
#  14. RMIT Vietnam University                                 -       78 occurrences
#  15. Le Hong Phong High School For The Gifted, HCMC, Vietnam -       74 occurrences
#  16. Foreign Trade University                                -       72 occurrences
#  17. VNU-HCM High School for the Gifted                      -       62 occurrences
#  18. Foreign Language Specialized School                     -       61 occurrences
#  19. Tran Dai Nghia Specialized High School                  -       57 occurrences
#  20. Chu Van An National High School                         -       50 occurrences
#  21. Western Sydney University                               -       49 occurrences
#  22. University Of Economics Ho Chi Minh City                -       45 occurrences
#  23. Macquarie University                                    -       44 occurrences
#  24. Deakin University                                       -       40 occurrences
#  25. University of Greenwich                                 -       38 occurrences
#  26. La Trobe University                                     -       38 occurrences
#  27. University of Technology Sydney                         -       37 occurrences
#  28. University of Melbourne                                 -       36 occurrences
#  29. University of Staffordshire                             -       36 occurrences
#  30. SIM Global Education                                    -       34 occurrences
#  31. Singapore Institute of Management                       -       34 occurrences
#  32. ACCA                                                    -       32 occurrences
#  33. Tran Phu Gifted High School                             -       31 occurrences
#  34. International University - VNU HCMC                     -       29 occurrences
#  35. Vietnam National University, Hanoi                      -       29 occurrences
#  36. CFA Institute                                           -       27 occurrences
#  37. National Economics University (NEU) Vietnam             -       26 occurrences
#  38. Saigon International College                            -       25 occurrences
#  39. VNUHCM - University of Science                          -       24 occurrences
#  40. RMIT University, Vietnam                                -       24 occurrences
#  41. University of London                                    -       23 occurrences
#  42. University of Sydney                                    -       22 occurrences
#  43. UNIVERSITY OF SOCIAL SCIENCES AND HUMANITIES (USSH)     -       22 occurrences
#  44. National Economics University (Vietnam)                 -       22 occurrences
#  45. UNSW                                                    -       22 occurrences
#  46. FPT University                                          -       21 occurrences
#  47. Bournemouth University                                  -       20 occurrences
#  48. Quốc Học – Huế High School for the Gifted               -       20 occurrences
#  49. CPA Australia                                           -       19 occurrences
#  50. Hoa Sen University (Not for Profit)                     -       19 occurrences
#  51. Vietnam Australia International School                  -       19 occurrences
#  52. University of Southampton                               -       18 occurrences
#  53. Ho Chi Minh City University of Law (ULAW)               -       18 occurrences
#  54. Le Quy Don High School for the Gifted                   -       18 occurrences
#  55. RMIT International University, Vietnam                  -       18 occurrences
#  56. Curtin University                                       -       17 occurrences
#  57. Humber College                                          -       17 occurrences
#  58. Massey University                                       -       17 occurrences
#  59. Nguyen Thi Minh Khai High School, HCM                   -       17 occurrences
#  60. Nguyen Thuong Hien High School For The Gifted, HCMC,... -       16 occurrences
#  61. High School for Gifted Students, Hanoi National Univ... -       16 occurrences
#  62. RMIT Vietnam International University                   -       16 occurrences
#  63. High School for Gifted Students, Hanoi University of... -       15 occurrences
#  64. Coventry University                                     -       15 occurrences
#  65. University of Portsmouth                                -       15 occurrences
#  66. High School for Gifted Students, Hanoi University of... -       15 occurrences
#  67. Nguyen Hue High School for the Gifted                   -       15 occurrences
#  68. The Asian International School                          -       14 occurrences
#  69. Ho Chi Minh University of Technology                    -       14 occurrences
#  70. French Vietnamese School of Management (CFVG)           -       14 occurrences
#  71. George Brown College                                    -       14 occurrences
#  72. Vinschool                                               -       14 occurrences
#  73. Griffith University                                     -       14 occurrences
#  74. Singapore International School (SIS)                    -       14 occurrences
#  75. National University of Singapore                        -       14 occurrences
#  76. Nanyang Technological University Singapore              -       14 occurrences
#  77. Victoria University                                     -       13 occurrences
#  78. Hanoi University                                        -       13 occurrences
#  79. Monash College                                          -       13 occurrences
#  80. Solvay Brussels School                                  -       13 occurrences
#  81. The University of Queensland                            -       13 occurrences
#  82. Seattle Central College                                 -       13 occurrences
#  83. Columbia Southern University                            -       12 occurrences
#  84. University of Westminster                               -       12 occurrences
#  85. Ryerson University                                      -       12 occurrences
#  86. QUT (Queensland University of Technology)               -       12 occurrences
#  87. Hanoi University of Science and Technology              -       12 occurrences
#  88. Le Quy Don High School for the Gifted-Danang            -       12 occurrences
#  89. Columbia International College                          -       12 occurrences
#  90. Cornell University                                      -       12 occurrences
#  91. University of Birmingham                                -       12 occurrences
#  92. Hoa Sen University                                      -       12 occurrences
#  93. Aston University                                        -       12 occurrences
#  94. Australian Institute of Business                        -       12 occurrences
#  95. Golden Gate University                                  -       12 occurrences
#  96. UEH - International School of Business                  -       12 occurrences
#  97. CPA Australia Program                                   -       11 occurrences
#  98. Ton Duc Thang University                                -       11 occurrences
#  99. Phan Chau Trinh High School of Danang                   -       11 occurrences
# 100. Northeastern University                                 -       11 occurrences
#
# ======================================================================
# Total unique universities: 3,435
# Total education entries processed: 22,388
# /tmp/ipykernel_133107/1868129610.py:26: DeprecationWarning: `Expr.str.json_decode` with `infer_schema_length` is deprecated and has no effect on execution.
#   pl.col("educations").str.json_decode(dtype=education_schema, infer_schema_length=1000)

# %%
import polars as pl

# 1. Load the dataset
df = pl.read_csv("../Data/final.csv")


# 3. Count occurrences for an array of university names
target_universities = ["BUV", "British University Vietnam", "Swinburne", "FUV", "Fulbright University Vietnam", "RMIT","Royal Melbourne Institute of Technology Vietnam","VinUniversity","VIN"]

# Parse the JSON strings, explode the list into individual rows, and extract the university field
df_unis = (
    df.select(pl.col("educations").str.json_decode(edu_schema))
    .explode("educations")
    .select(pl.col("educations").struct.field("university").str.to_lowercase().alias("uni_name"))
    .filter(pl.col("uni_name").is_not_null())
)

# Compute the case-insensitive substring match count for each name in the array
university_counts = {
    uni: df_unis.filter(pl.col("uni_name").str.contains(uni.lower())).height
    for uni in target_universities
}

print("University Occurrences:", university_counts)
# Out:
# University Occurrences: {'BUV': 29, 'British University Vietnam': 841, 'Swinburne': 1149, 'FUV': 1, 'Fulbright University Vietnam': 642, 'RMIT': 15165, 'Royal Melbourne Institute of Technology Vietnam': 3, 'VinUniversity': 353, 'VIN': 3963}

# %%
import polars as pl

# 1. Load the dataset
df = pl.read_csv("../../Data/final.csv")

# Update schema to include degree_standardized
edu_schema = pl.List(pl.Struct({
    "university": pl.String,
    "degree_standardized": pl.String,
    "end_date": pl.String
}))

# Target universities list
target_universities = [
    "BUV", "British University Vietnam", "Swinburne", "FUV", 
    "Fulbright University Vietnam", "RMIT", "Royal Melbourne Institute of Technology Vietnam",
    "VinUniversity"
]
pattern = "|".join([uni.lower() for uni in target_universities])

# 2. Extract unique row IDs matching both university and bachelor degree criteria
matching_ids = (
    df.select(["id", pl.col("educations").str.json_decode(edu_schema)])
    .explode("educations")
    .filter(
        (pl.col("educations").struct.field("university").str.to_lowercase().str.contains(pattern)) &
        (pl.col("educations").struct.field("degree_standardized") == "bachelor") &
        (pl.col("educations").struct.field("end_date").is_in(["2027-01-01", "2026-01-01", "2025-01-01", "2024-01-01"]))
    )
    .select("id")
    .unique()
)

# 3. Filter the original DataFrame and export to CSV
filtered_df = df.join(matching_ids, on="id", how="inner")
filtered_df.write_csv("fresh-grad-filter.csv")
