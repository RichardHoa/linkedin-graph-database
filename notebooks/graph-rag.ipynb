# %%
# !pip install --upgrade pip
# !pip install neo4j neo4j-graphrag openai python-dotenv
# Out:
# Requirement already satisfied: pip in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (24.0)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.0 MB/s eta 0:00:00 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-26.0.1
# Requirement already satisfied: neo4j in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (5.28.3)
# Collecting neo4j-graphrag
#   Downloading neo4j_graphrag-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting openai
#   Downloading openai-2.21.0-py3-none-any.whl.metadata (29 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pytz in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from neo4j) (2025.2)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag)
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from neo4j-graphrag) (2.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from neo4j-graphrag) (2.12.5)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag)
#   Downloading pypdf-6.7.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from neo4j-graphrag) (6.0.3)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from neo4j-graphrag) (1.16.3)
# Collecting tenacity<10.0.0,>=9.1.2 (from neo4j-graphrag)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting types-pyyaml<7.0.0,>=6.0.12.20240917 (from neo4j-graphrag)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.6.3->neo4j-graphrag) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.6.3->neo4j-graphrag) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.6.3->neo4j-graphrag) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.6.3->neo4j-graphrag) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from openai) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/danghoa/graph-database/jupyter_env/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Downloading neo4j_graphrag-1.13.0-py3-none-any.whl (222 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading pypdf-6.7.0-py3-none-any.whl (330 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Downloading openai-2.21.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.1 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: types-pyyaml, tenacity, sniffio, python-dotenv, pypdf, json-repair, jiter, fsspec, distro, openai, neo4j-graphrag
#   Attempting uninstall: fsspec╸━━━━━━━━━━━━━━━━━━  6/11 [jiter]
#     Found existing installation: fsspec 2026.1.0━━━━━━━━━━━━━━  6/11 [jiter]
#     Uninstalling fsspec-2026.1.0:m╸━━━━━━━━━━━━━━━━━━  6/11 [jiter]
#       Successfully uninstalled fsspec-2026.1.0━━━━━━━━━━━━━━━━  6/11 [jiter]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [neo4j-graphrag]m [openai]
# Successfully installed distro-1.9.0 fsspec-2024.12.0 jiter-0.13.0 json-repair-0.44.1 neo4j-graphrag-1.13.0 openai-2.21.0 pypdf-6.7.0 python-dotenv-1.2.1 sniffio-1.3.1 tenacity-9.1.4 types-pyyaml-6.0.12.20250915

# %%
import os
from dotenv import load_dotenv

# Load variables from .env
load_dotenv()

# Verify the key is loaded (optional check)
if not os.getenv("OPENAI_API_KEY"):
    print("Error: OpenAI API Key not found!")
